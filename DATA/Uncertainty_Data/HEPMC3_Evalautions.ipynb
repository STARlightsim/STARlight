# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-892896d8-8560-49c7-9d5d-b946068be26d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-892896d8-8560-49c7-9d5d-b946068be26d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #Lead-Lead Collision -------- J/\psi -> e^+e^-
# Lead-γ = 1460, Lead - γ = 1460
#
# Lead = 195.160585568 Lead = 195.160585568

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Read the CSV file into a pandas DataFrame
dfJL = pd.read_csv('Test_UPJeAbsdev1.csv', delimiter = ' ')
dfJL
# Out:
#        PzGamA    PzGamB         Pz  PzGamA_dev  PzGamB_dev  PzGamA_devRat  \
# 0    0.518324  0.518301  -4.109794    0.000098    0.000080       0.000189
# 1   -1.258095 -1.258073   0.648025    0.000094    0.000077      -0.000075
# 2    0.274941  0.274935  -8.447544    0.000022    0.000018       0.000079
# 3    0.733060  0.733020  -2.539020    0.000168    0.000137       0.000229
# 4   -0.118428 -0.118419  20.135205    0.000042    0.000034      -0.000352
# ..        ...       ...        ...         ...         ...            ...
# 995 -0.024901 -0.024896  96.323416    0.000018    0.000015      -0.000714
# 996 -3.635987 -3.634879  -2.975341    0.004703    0.003840      -0.001294
# 997 -4.300230 -4.299522  -3.742144    0.003003    0.002452      -0.000698
# 998  0.503976  0.503975  -4.253919    0.000004    0.000003       0.000008
# 999 -3.727119 -3.726598  -3.083269    0.002211    0.001805      -0.000593
#
#      PzGamB_devRat      PzPom  PzPom_dev  PzPom_devRat  totalDev    Q2gamA  \
# ...

# %%
dfJL.sort_values(by=["PzGamA_devRat"],ascending=False)
# Out:
#        PzGamA    PzGamB          Pz  PzGamA_dev  PzGamB_dev  PzGamA_devRat  \
# 271  0.725043  0.723438   -2.626299    0.006811    0.005561       0.009394
# 74   0.032093  0.032069  -74.984553    0.000098    0.000080       0.003066
# 166  0.103212  0.103141  -23.222623    0.000298    0.000243       0.002887
# 511  1.077129  1.076411   -1.157561    0.003049    0.002489       0.002831
# 809  0.881007  0.880497   -1.850142    0.002167    0.001769       0.002460
# ..        ...       ...         ...         ...         ...            ...
# 52  -0.036253 -0.036226   66.376444    0.000112    0.000092      -0.003092
# 31  -0.796250 -0.795659    2.228403    0.002509    0.002048      -0.003151
# 813 -1.134001 -1.133009    0.991536    0.004208    0.003436      -0.003711
# 394 -0.014077 -0.014062  171.111154    0.000060    0.000049      -0.004282
# 16  -3.723174 -3.718653   -3.074503    0.019180    0.015661      -0.005152
#
# ...

# %%
dfJL1 = dfJL["PzGamA_devRat"]*100
dfJL2 = dfJL["PzGamB_devRat"]*100
dfJL3 = dfJL["totalDev"]
dfJL4 = dfJL["Q2gamA"]*-1
dfJL5 = dfJL["Q2gamB"]*-1

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfJL1, bins=np.logspace(start=np.log10(10**(-6)), stop=np.log10(10), num=35))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
dfJL6 = dfJL["PzGamA_dev"]-dfJL["PzGamB_dev"]
min(dfJL6), max(dfJL6)
# Out:
# (1.3232545986457694e-08, 0.0035196398621503006)

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfJL6, bins=np.logspace(start=np.log10(10**(-8)), stop=np.log10(10**(-2)), num=35))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfJL2, bins=np.logspace(start=np.log10(10**(-6)), stop=np.log10(10), num=35))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
min(dfJL4), max(dfJL4)
# Out:
# (5.9464536504919e-07, 0.42506625411238)

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfJL5, bins=np.logspace(start=np.log10(10**(-7)), stop=np.log10(1), num=35))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
dfJL6 = dfJL["PzGamA_dev"]-dfJL["PzGamB_dev"]
min(dfJL6), max(dfJL6)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b5d3382a-1955-4ce8-aa1d-3cb3023c9d7a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b5d3382a-1955-4ce8-aa1d-3cb3023c9d7a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### Proton-Lead Collision -  Pz-Gamma Test J/\psi ->e^+e^-
#  Proton-γ = 4260, Lead - γ = 1460
#
#  Proton  = 0.938272046
#  Lead = 195.160585568

# %%
# Read the CSV file into a pandas DataFrame
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
dfJQ = pd.read_csv('Test_UPJeAbsdev2.csv', delimiter = ' ')
dfJQ
# Out:
#        PzGamA    PzGamB         Pz  PzGamA_dev  PzGamB_dev  PzGamA_devRat  \
# 0    0.518292  0.518279  -4.109545    0.000053    0.000044       0.000103
# 1    0.275070  0.275022  -8.451515    0.000203    0.000165       0.000736
# 2    0.039819  0.039810 -60.249072    0.000036    0.000029       0.000905
# 3    4.615125  4.614930   4.095467    0.000827    0.000675       0.000179
# 4    0.046762  0.046755 -51.258829    0.000030    0.000024       0.000635
# ..        ...       ...        ...         ...         ...            ...
# 995  9.452654  9.384398   9.187584    0.289583    0.236444       0.030635
# 996  0.782295  0.782183  -2.285513    0.000475    0.000388       0.000607
# 997  0.123344  0.123333 -19.322777    0.000045    0.000037       0.000363
# 998  1.606598  1.606489   0.113612    0.000461    0.000377       0.000287
# 999  3.997516  3.993701   3.394245    0.016185    0.013215       0.004049
#
#      PzGamB_devRat      PzPom  PzPom_dev  PzPom_devRat  totalDev    Q2gamA  \
# ...

# %%
dfJQ.sort_values(by=["PzGamA_devRat"],ascending=False)
# Out:
#         PzGamA     PzGamB         Pz  PzGamA_dev    PzGamB_dev  PzGamA_devRat  \
# 500  15.196626  14.949557  15.022150    1.048226  8.558731e-01       0.068978
# 699   0.185502   0.183379 -13.693976    0.009007  7.354139e-03       0.048554
# 355   0.726395   0.719459  -2.773002    0.029429  2.402861e-02       0.040514
# 75    0.470291   0.466678  -4.873214    0.015329  1.251577e-02       0.032594
# 35    0.754205   0.748514  -2.574813    0.024148  1.971690e-02       0.032018
# ..         ...        ...        ...         ...           ...            ...
# 385  28.971482  28.971451  28.888737    0.000132  1.078165e-04       0.000005
# 866   0.570265   0.570264  -3.634285    0.000002  2.000529e-06       0.000004
# 406   0.591685   0.591685  -3.460549    0.000001  9.843001e-07       0.000002
# 175  13.000996  13.000991  12.816563    0.000024  1.969159e-05       0.000002
# 566  15.656967  15.656962  15.503830    0.000024  1.952940e-05       0.000002
#
# ...

# %%
dfJQ1 = dfJQ["PzGamA_devRat"]*100
dfJQ2 = dfJQ["PzGamB_devRat"]*100
dfJQ3 = dfJQ["totalDev"]
dfJQ4 = dfJQ["Q2gamA"]*-1
dfJQ5 = dfJQ["Q2gamB"]*-1

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfJQ1, bins=np.logspace(start=np.log10(10**(-5)), stop=np.log10(10**2), num=35))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfJQ2, bins=np.logspace(start=np.log10(10**(-5)), stop=np.log10(10**2), num=35))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
min(dfJQ4), max(dfJQ4)
# Out:
# (2.2692135698537e-07, 57.5785239644356)

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.hist(dfJQ4, bins=np.logspace(start=np.log10(10**(-7)), stop=np.log10(10**2), num=100))
plt.gca().set_xscale("log")
plt.show()

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfJQ5, bins=np.logspace(start=np.log10(10**(-7)), stop=np.log10(10**2), num=100))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
dfJQ6 = dfJQ["Q2gamB"] - dfJQ["Q2gamA"]
min(dfJQ6), max(dfJQ6)
# Out:
# (6.755005940001745e-08, 19.191771579942696)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6ffb67ed-8bcd-4c79-a8ea-d6f4705e3f81" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ffb67ed-8bcd-4c79-a8ea-d6f4705e3f81">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Proton-Proton Collision - Deviations in Momentum - Jpsi - e+e-
# ## Pz-Gamma1 Test, Pz Gamma2 Test, and PzGammaMean and  Test.
# Proton-γ = 4260, proton - γ = 4260
#
# B1_MASS = mass of proton
#
# B2_MASS = mass of proton
#
# Proton = 0.938272046 Proton = 0.938272046

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

dfJP = pd.read_csv('Test_UPJeAbsdev3.csv', delimiter = ' ')
dfJP
# Out:
#         PzGamA     PzGamB         Pz  PzGamA_dev  PzGamB_dev  PzGamA_devRat  \
# 0     0.050408   0.050164 -48.908079    0.001036    0.000846       0.020547
# 1    -4.225169  -4.213169  -3.648018    0.050913    0.041570      -0.012050
# 2    -5.989405  -5.883861  -5.543082    0.447784    0.365614      -0.074763
# 3     1.791778   1.787913   0.436124    0.016398    0.013389       0.009152
# 4    -0.030657  -0.030652  78.269143    0.000024    0.000020      -0.000790
# ..         ...        ...        ...         ...         ...            ...
# 995  -0.728165  -0.724162   2.676887    0.016982    0.013866      -0.023322
# 996 -24.236187 -24.133498 -24.134682    0.435675    0.355727      -0.017976
# 997  -0.295291  -0.294652   7.930841    0.002711    0.002214      -0.009181
# 998   0.111427   0.111080 -21.812233    0.001468    0.001199       0.013178
# 999   5.071411   5.060421   4.592365    0.046624    0.038068       0.009194
#
# ...

# %%
dfJP1 = dfJP["PzGamA_devRat"]*100
dfJP2 = dfJP["PzGamB_devRat"]*100
dfJP3 = dfJP["totalDev"]
dfJP4 = dfJP["Q2gamA"]*-1
dfJP5 = dfJP["Q2gamB"]*-1

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfJP1, bins=np.logspace(start=np.log10(10**(-5)), stop=np.log10(10**2), num=35))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfJP2, bins=np.logspace(start=np.log10(10**(-5)), stop=np.log10(10**2), num=35))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
min(dfJP4), max(dfJP4)
# Out:
# (9.05134511457303e-08, 597721.946626503)

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.hist(dfJP4, bins=np.logspace(start=np.log10(10**(-8)), stop=np.log10(10**7), num=100))
plt.gca().set_xscale("log")
plt.show()

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfJP5, bins=np.logspace(start=np.log10(10**(-8)), stop=np.log10(10**7), num=100))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0985cd9c-b42b-460b-a1eb-0f39d408b76a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0985cd9c-b42b-460b-a1eb-0f39d408b76a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #Lead-Lead Collision -------- \omega -> \pi^+\pi^-
# Lead-γ = 1460, Lead - γ = 1460
#
# Lead = 195.160585568 Lead = 195.160585568

# %%
 # Read the CSV file into a pandas DataFrame
dfOL = pd.read_csv('Test_UPO3PAbsdev1.csv', delimiter = ' ')
dfOL
# Out:
#         PzGamA    PzGamB          Pz  PzGamA_dev  PzGamB_dev  PzGamA_devRat  \
# 0     0.012360  0.012357  -11.995767    0.000014    0.000011       0.001127
# 1    -0.088108 -0.088049    1.635762    0.000251    0.000205      -0.002850
# 2    -0.002359 -0.002355   65.686714    0.000019    0.000015      -0.007902
# 3    -0.001117 -0.001111  138.434989    0.000024    0.000020      -0.021837
# 4    -0.008709 -0.008708   17.664599    0.000004    0.000004      -0.000514
# ...        ...       ...         ...         ...         ...            ...
# 1646 -0.230840 -0.230545    0.417660    0.001252    0.001022      -0.005422
# 1647  1.363604  1.362734    1.250229    0.003687    0.003011       0.002704
# 1648  0.012748  0.012742  -11.993075    0.000025    0.000020       0.001957
# 1649 -0.311881 -0.311526    0.181045    0.001506    0.001229      -0.004828
# 1650 -0.058754 -0.058741    2.555441    0.000053    0.000043      -0.000906
#
# ...

# %%
dfOL1 = dfOL["PzGamA_devRat"]*100
dfOL2 = dfOL["PzGamB_devRat"]*100
dfOL3 = dfOL["totalDev"]
dfOL4 = dfOL["Q2gamA"]*-1
dfOL5 = dfOL["Q2gamB"]*-1

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.hist(dfOL1, bins=np.logspace(start=np.log10(10**(-5)), stop=np.log10(10**2), num=35))
plt.gca().set_xscale("log")
plt.show()

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfOL2, bins=np.logspace(start=np.log10(10**(-5)), stop=np.log10(10**2), num=35))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
min(dfOL4), max(dfOL4)
# Out:
# (3.54400247661981e-08, 13.2116931547262)

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfOL4, bins=np.logspace(start=np.log10(10**(-9)), stop=np.log10(10**2), num=100))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfOL5, bins=np.logspace(start=np.log10(10**(-9)), stop=np.log10(10**2), num=100))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-35033c85-9230-434e-bcb2-0c22ba82c64e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-35033c85-9230-434e-bcb2-0c22ba82c64e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### Proton-Lead Collision -  Pz-Gamma Test \omega ->\pi^+\pi^-\pi^0
#  Proton-γ = 4260, Lead - γ = 1460
#
#  Proton  = 0.938272046
#  Lead = 195.160585568

# %%
 # Read the CSV file into a pandas DataFrame
dfOQ = pd.read_csv('Test_UPO3PAbsdev2.csv', delimiter = ' ')
dfOQ
# Out:
#         PzGamA    PzGamB          Pz  PzGamA_dev  PzGamB_dev  PzGamA_devRat  \
# 0     0.012389  0.012376  -12.024357    0.000054    0.000044       0.004382
# 1     2.016500  2.015138    1.940325    0.005781    0.004720       0.002867
# 2     8.435009  8.429805    8.417544    0.022076    0.018025       0.002617
# 3     0.281701  0.278965   -0.302642    0.011609    0.009479       0.041210
# 4     0.005392  0.005387  -27.366054    0.000022    0.000018       0.004081
# ...        ...       ...         ...         ...         ...            ...
# 1577  0.000930  0.000927 -165.180047    0.000010    0.000008       0.010593
# 1578  0.007694  0.007676  -19.761599    0.000074    0.000060       0.009618
# 1579  0.001199  0.001195 -130.101545    0.000016    0.000013       0.013212
# 1580  0.027902  0.027842   -5.331588    0.000252    0.000206       0.009024
# 1581  3.425145  3.395619    3.377479    0.125266    0.102279       0.036572
#
# ...

# %%
dfOQ.sort_values(by=["PzGamA_devRat"],ascending=False)
# Out:
#         PzGamA    PzGamB         Pz    PzGamA_dev    PzGamB_dev  \
# 708   1.250573  1.106947   0.959374  6.093521e-01  4.975339e-01
# 961   0.008997  0.007969 -41.927250  4.364191e-03  3.563347e-03
# 668   0.006446  0.005808 -50.094001  2.705186e-03  2.208775e-03
# 1542  0.011652  0.010585 -25.203153  4.527929e-03  3.697039e-03
# 1228  3.044949  2.783892   2.952929  1.107574e+00  9.043306e-01
# ...        ...       ...        ...           ...           ...
# 1007  0.630842  0.630837   0.372886  2.283313e-05  1.864317e-05
# 1549  0.775545  0.775540   0.568036  1.987111e-05  1.622469e-05
# 492   0.192420  0.192419  -0.628407  4.583860e-06  3.742706e-06
# 1526  0.033263  0.033263  -4.402191  7.465708e-07  6.095725e-07
# 886   0.164663  0.164663  -0.764656  4.837212e-07  3.949567e-07
#
#       PzGamA_devRat  PzGamB_devRat      PzPom     PzPom_dev  PzPom_devRat  \
# 708        0.487258       0.449465  -0.434825  4.975339e-01 -1.144218e+00
# ...

# %%
dfOQ1 = dfOQ["PzGamA_devRat"]*100
dfOQ2 = dfOQ["PzGamB_devRat"]*100
dfOQ3 = dfOQ["totalDev"]
dfOQ4 = dfOQ["Q2gamA"]*-1
dfOQ5 = dfOQ["Q2gamB"]*-1

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfOQ1, bins=np.logspace(start=np.log10(10**(-5)), stop=np.log10(10**2), num=35))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfOQ2, bins=np.logspace(start=np.log10(10**(-5)), stop=np.log10(10**2), num=35))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7042fc24-f666-4e33-b1cb-fc9ac3ee7861" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7042fc24-f666-4e33-b1cb-fc9ac3ee7861">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Proton-Proton Collision - Deviations in Momentum - \omega -> \pi^+\pi^-\pi^0
# ## Pz-Gamma1 Test, Pz Gamma2 Test, and PzGammaMean and  Test.
# Proton-γ = 4260, proton - γ = 4260
#
# B1_MASS = mass of proton
#
# B2_MASS = mass of proton
#
# Proton = 0.938272046 Proton = 0.938272046

# %%
dfOP = pd.read_csv('Test_UPO3PAbsdev3.csv', delimiter = ' ')
dfOP
# Out:
#           PzGamA      PzGamB          Pz  PzGamA_dev  PzGamB_dev  \
# 0      -0.000882   -0.000869  187.567463    0.000057    0.000047
# 1      -9.880699   -9.530792   -9.861263    1.484529    1.212113
# 2      -0.000305   -0.000298  537.352975    0.000031    0.000025
# 3       0.324156    0.323205   -0.153691    0.004034    0.003294
# 4       0.000483    0.000480 -326.656444    0.000015    0.000012
# ...          ...         ...         ...         ...         ...
# 1507   -0.001681   -0.001620  111.029589    0.000258    0.000210
# 1508   -0.005849   -0.005830   26.773376    0.000083    0.000067
# 1509    0.218998    0.212683   -0.636585    0.026791    0.021875
# 1510 -118.352471 -118.219571 -118.351186    0.563848    0.460380
# 1511   -0.019399   -0.018775    9.728260    0.002647    0.002161
#
#       PzGamA_devRat  PzGamB_devRat       PzPom  PzPom_dev  PzPom_devRat  \
# 0         -0.064898      -0.053812  187.568358   0.000047  2.491955e-07
# ...

# %%
dfOP1 = dfOP["PzGamA_devRat"]*100
dfOP2 = dfOP["PzGamB_devRat"]*100
dfOP3 = dfOP["totalDev"]
dfOP4 = dfOP["Q2gamA"]*-1
dfOP5 = dfOP["Q2gamB"]*-1

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.hist(dfOP1, bins=np.logspace(start=np.log10(10**(-4)), stop=np.log10(10**3), num=35))
plt.gca().set_xscale("log")
plt.show()

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfOP2, bins=np.logspace(start=np.log10(10**(-4)), stop=np.log10(10**3), num=35))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
min(dfOP4), max(dfOP4)
# Out:
# (5.1234670985376e-09, 929583.801397552)

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.hist(dfOP4, bins=np.logspace(start=np.log10(10**(-9)), stop=np.log10(10**7), num=100))
plt.gca().set_xscale("log")
plt.show()

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfOP5, bins=np.logspace(start=np.log10(10**(-9)), stop=np.log10(10**7), num=100))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ef9c5d03-5e97-4b4b-ac01-1b933820ab87" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ef9c5d03-5e97-4b4b-ac01-1b933820ab87">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #Lead-Lead Collision - Rho -> e^+ e^-
# Lead-γ = 1460, Lead - γ = 1460
#
# Lead = 195.160585568 Lead = 195.160585568

# %%
dfRL = pd.read_csv('Test_UPReAbsdev1.csv', delimiter = ' ')
dfRL
# Out:
#        PzGamA    PzGamB         Pz  PzGamA_dev  PzGamB_dev  PzGamA_devRat  \
# 0   -0.068226 -0.068064   1.892977    0.000685    0.000560      -0.010045
# 1   -0.027113 -0.027093   3.849625    0.000088    0.000072      -0.003248
# 2   -0.156337 -0.156131   0.732008    0.000875    0.000715      -0.005599
# 3   -0.005491 -0.005488  47.104299    0.000012    0.000010      -0.002269
# 4    0.004367  0.004364 -44.655621    0.000016    0.000013       0.003687
# ..        ...       ...        ...         ...         ...            ...
# 995  0.013597  0.013590 -25.511639    0.000032    0.000026       0.002324
# 996 -0.063088 -0.063059   3.272258    0.000125    0.000102      -0.001984
# 997 -0.110385 -0.110293   1.294550    0.000388    0.000317      -0.003518
# 998  0.003231  0.003228 -64.562825    0.000015    0.000012       0.004572
# 999 -0.053511 -0.053483   3.651702    0.000119    0.000097      -0.002225
#
#      PzGamB_devRat      PzPom  PzPom_dev  PzPom_devRat  totalDev  \
# ...

# %%
dfRL1 = dfRL["PzGamA_devRat"]*100
dfRL2 = dfRL["PzGamB_devRat"]*100
dfRL3 = dfRL["totalDev"]
dfRL4 = dfRL["Q2gamA"]*-1
dfRL5 = dfRL["Q2gamB"]*-1

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfRL1, bins=np.logspace(start=np.log10(10**(-4)), stop=np.log10(10**3), num=35))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfRL2, bins=np.logspace(start=np.log10(10**(-4)), stop=np.log10(10**3), num=35))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
min(dfRL4), max(dfRL4)
# Out:
# (2.33393874687905e-08, 2.17421108603432)

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.hist(dfRL4, bins=np.logspace(start=np.log10(10**(-9)), stop=np.log10(10**2), num=100))
plt.gca().set_xscale("log")
plt.show()

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfRL5, bins=np.logspace(start=np.log10(10**(-9)), stop=np.log10(10**2), num=100))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bd2c002f-43e1-42e5-843c-ba6ef31e118b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bd2c002f-43e1-42e5-843c-ba6ef31e118b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### Proton-Lead Collision -  Pz-Gamma Test \rho -> e^+e^-
#  Proton-γ = 4260, Lead - γ = 1460
#
#  Proton  = 0.938272046
#  Lead = 195.160585568

# %%
dfRQ = pd.read_csv('Test_UPReAbsdev2.csv', delimiter = ' ')
dfRQ
# Out:
#        PzGamA    PzGamB          Pz  PzGamA_dev  PzGamB_dev  PzGamA_devRat  \
# 0    1.947326  1.947310    1.879583    0.000065    0.000053       0.000033
# 1    0.085328  0.085173   -2.621674    0.000656    0.000535       0.007685
# 2    0.063899  0.062878   -5.734719    0.004333    0.003538       0.067813
# 3    5.141583  5.090356    5.119842    0.217339    0.177457       0.042271
# 4    0.003609  0.003606  -63.227913    0.000014    0.000011       0.003822
# ..        ...       ...         ...         ...         ...            ...
# 995  1.459661  1.459397    1.368272    0.001122    0.000916       0.000769
# 996  0.008054  0.008026  -14.050564    0.000119    0.000097       0.014769
# 997  6.263497  6.171848    6.225602    0.388835    0.317483       0.062080
# 998  0.244540  0.244383   -0.211037    0.000666    0.000544       0.002722
# 999  0.001821  0.001802 -119.234126    0.000080    0.000065       0.043763
#
#      PzGamB_devRat       PzPom  PzPom_dev  PzPom_devRat  totalDev  \
# ...

# %%
dfRQ.sort_values(by=["PzGamA_devRat"],ascending=False)
# Out:
#        PzGamA    PzGamB          Pz    PzGamA_dev    PzGamB_dev  \
# 522  0.540218  0.482197    0.047611  2.461637e-01  2.009918e-01
# 829  0.040165  0.036412   -6.962338  1.592267e-02  1.300081e-02
# 610  0.801332  0.730354    0.454933  3.011356e-01  2.458762e-01
# 815  6.902919  6.344798    6.858710  2.367907e+00  1.933388e+00
# 900  0.001403  0.001297 -224.990616  4.510928e-04  3.683158e-04
# ..        ...       ...         ...           ...           ...
# 236  0.228808  0.228806   -0.622990  6.768759e-06  5.526668e-06
# 824  2.056719  2.056706    1.998577  5.310383e-05  4.335910e-05
# 345  0.911228  0.911224    0.504437  1.934965e-05  1.579893e-05
# 287  0.071284  0.071284   -1.989319  3.902420e-07  3.186312e-07
# 752  0.102489  0.102489   -1.520523  2.045977e-07  1.670533e-07
#
#      PzGamA_devRat  PzGamB_devRat       PzPom     PzPom_dev  PzPom_devRat  \
# 522       0.455674       0.416825   -0.550628  2.009918e-01 -3.650226e-01
# ...

# %%
dfRQ1 = dfRQ["PzGamA_devRat"]*100
dfRQ2 = dfRQ["PzGamB_devRat"]*100
dfRQ3 = dfRQ["totalDev"]
dfRQ4 = dfRQ["Q2gamA"]*-1
dfRQ5 = dfRQ["Q2gamB"]*-1

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.hist(dfRQ1, bins=np.logspace(start=np.log10(10**(-4)), stop=np.log10(10**3), num=35))
plt.gca().set_xscale("log")
plt.show()

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfRQ2, bins=np.logspace(start=np.log10(10**(-4)), stop=np.log10(10**3), num=35))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-14d6f94a-cd9f-4249-a988-f9bd82d265e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-14d6f94a-cd9f-4249-a988-f9bd82d265e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## Proton-Proton Collision - Deviations in Momentum - Rho -> mu^+ mu^-
# ## Pz-Gamma1 Test, Pz Gamma2 Test, and PzGammaMean Test.
# Proton-γ = 4260, proton - γ = 4260
#
# B1_MASS = mass of proton
#
# B2_MASS = mass of proton
#
# Proton = 0.938272046 Proton = 0.938272046

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Read the CSV file into a pandas DataFrame
dfRP = pd.read_csv('Test_UPReAbsdev3.csv', delimiter = ' ')
dfRP
# Out:
#        PzGamA    PzGamB           Pz  PzGamA_dev  PzGamB_dev  PzGamA_devRat  \
# 0    2.553616  2.351511     2.464766    0.857455    0.700109       0.335781
# 1    0.034561  0.033727    -5.338752    0.003540    0.002890       0.102423
# 2   -0.000146 -0.000129  1599.990460    0.000075    0.000062      -0.515152
# 3    0.059971  0.055934    -2.230724    0.017127    0.013984       0.285595
# 4    0.005700  0.005689   -24.485326    0.000045    0.000036       0.007814
# ..        ...       ...          ...         ...         ...            ...
# 995 -0.005681 -0.005619    29.048583    0.000261    0.000213      -0.045998
# 996  0.494428  0.460055     0.056602    0.145834    0.119073       0.294954
# 997  0.011681  0.011273   -15.540561    0.001727    0.001410       0.147881
# 998  0.487294  0.474550     0.068869    0.054067    0.044145       0.110953
# 999  1.646008  1.644010     1.555541    0.008474    0.006919       0.005148
#
# ...

# %%
dfRP1 = dfRP["PzGamA_devRat"]*100
dfRP2 = dfRP["PzGamB_devRat"]*100
dfRP3 = dfRP["totalDev"]
dfRP4 = dfRP["Q2gamA"]*-1
dfRP5 = dfRP["Q2gamB"]*-1

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfRP1, bins=np.logspace(start=np.log10(10**(-4)), stop=np.log10(10**3), num=35))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
len(dfRP2[dfRP2 > 100])
# Out:
# 23

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfRP2, bins=np.logspace(start=np.log10(10**(-4)), stop=np.log10(10**3), num=35))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()

# %%
min(dfRP4), max(dfRP4)
# Out:
# (1.2068822794035702e-09, 1733669.81685159)

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.hist(dfRP4, bins=np.logspace(start=np.log10(10**(-9)), stop=np.log10(10**8), num=100))
plt.gca().set_xscale("log")
plt.show()

# %%
plt.rc('font',size=18)
plt.rcParams['figure.figsize'] = [12, 8]
ax1 = plt.subplot()
plt.hist(dfRP5, bins=np.logspace(start=np.log10(10**(-9)), stop=np.log10(10**8), num=100))
plt.gca().set_xscale("log")
ax1.minorticks_on()
ax1.tick_params('both', length=15, width=2, which='major')
ax1.tick_params('both', length=7, width=1, which='minor')
plt.show()
